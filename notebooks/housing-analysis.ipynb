# %% [markdown]
# # Housing data prediction
# Goal is to predict either the price of a house or area (size).

# %%
import pandas as pd
import matplotlib
import seaborn as sns

# %%
df = pd.read_csv('../datasets/housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parkingspots  prefarea  \
# ...

# %% [markdown]
# ## Numerical boolean denotation
# 0 = False
# 1 = True
#
# ## furnishingstatus denotation
# 0 = Unfurnished
# 1 = Semi-furnished
# 2 = Furnished

# %%
for col in df.columns:
    if isinstance(df[col][0], str):
        if col != 'furnishingstatus':
            df[col].replace({'no': 0, 'yes': 1}, inplace=True)
        else:
            df[col].replace({'unfurnished': 0, 'semi-furnished': 1, 'furnished': 2}, inplace=True)

# %% [markdown]
# ## Data viz to determine appropriate model

# %% [markdown]
# ### Categorical plots

# %%
sns.catplot(df, x='bedrooms', y='price', hue='furnishingstatus', kind='bar')

# %%
sns.catplot(df, x='bedrooms', y='price', kind='box')

# %%
sns.catplot(df, x='furnishingstatus', y='price', kind='box')

# %%
sns.catplot(df, x='prefarea', y='price', kind='box')

# %%
sns.catplot(df, x='mainroad', y='price', kind='box')

# %% [markdown]
# ### Relational plots

# %%
sns.relplot(df, x='area', y='price', markers=True, dashes=True, hue='bedrooms', style='bedrooms', palette="ch:r=-.9,l=.8")

# %%
sns.relplot(df, x='area', y='price', markers=True, dashes=True, hue='prefarea', style='prefarea')
